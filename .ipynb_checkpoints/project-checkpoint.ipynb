# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# [1] "fifa-19-dataset"

# %% [markdown]
# ## Data Source: [link](https://github.com/kiat/R-Examples/blob/master/projects/datasets/project-10.csv)

# %%
data <- read.csv('/kaggle/input/fifa-19-dataset/project-10.csv')

# %%
glimpse(data)
# Out:
# Rows: 500
# Columns: 15
# $ ID               <int> 158023, 20801, 190871, 193080, 192985, 183277, 177003…
# $ Name             <chr> "L. Messi", "Cristiano Ronaldo", "Neymar Jr", "De Gea…
# $ Age              <int> 31, 33, 26, 27, 27, 27, 32, 31, 32, 25, 29, 28, 32, 3…
# $ Nationality      <chr> "Argentina", "Portugal", "Brazil", "Spain", "Belgium"…
# $ Overall          <int> 94, 94, 92, 91, 91, 91, 91, 91, 91, 90, 90, 90, 90, 9…
# $ Potential        <int> 94, 94, 93, 93, 92, 91, 91, 91, 91, 93, 90, 90, 90, 9…
# $ Club             <chr> "FC Barcelona", "Juventus", "Paris Saint-Germain", "M…
# $ Value_in_M       <dbl> 110.5, 77.0, 118.5, 72.0, 102.0, 93.0, 67.0, 80.0, 51…
# $ Wage_in_K        <int> 565, 405, 290, 260, 355, 340, 420, 455, 380, 94, 205,…
# $ Jersey_Number    <int> 10, 7, 10, 1, 7, 10, 10, 9, 15, 1, 9, 8, 10, 21, 13, …
# $ Height_in_Inches <int> 67, 74, 69, 76, 71, 68, 68, 72, 72, 74, 72, 72, 74, 6…
# $ Weight_in_lbs    <int> 159, 183, 150, 168, 154, 163, 146, 190, 181, 192, 176…
# $ Reactions        <int> 95, 96, 94, 90, 91, 90, 90, 92, 85, 86, 90, 89, 85, 9…
# $ Balance          <int> 95, 70, 84, 43, 77, 94, 94, 83, 66, 49, 78, 71, 54, 9…
# $ Strength         <int> 59, 79, 49, 64, 75, 66, 58, 83, 83, 78, 84, 73, 88, 5…

# %%
head(data)
# Out:
#   ID     Name              Age Nationality Overall Potential
# 1 158023 L. Messi          31  Argentina   94      94
# 2  20801 Cristiano Ronaldo 33  Portugal    94      94
# 3 190871 Neymar Jr         26  Brazil      92      93
# 4 193080 De Gea            27  Spain       91      93
# 5 192985 K. De Bruyne      27  Belgium     91      92
# 6 183277 E. Hazard         27  Belgium     91      91
#   Club                Value_in_M Wage_in_K Jersey_Number Height_in_Inches
# 1 FC Barcelona        110.5      565       10            67
# 2 Juventus             77.0      405        7            74
# 3 Paris Saint-Germain 118.5      290       10            69
# 4 Manchester United    72.0      260        1            76
# 5 Manchester City     102.0      355        7            71
# 6 Chelsea              93.0      340       10            68
#   Weight_in_lbs Reactions Balance Strength
# 1 159           95        95      59
# 2 183           96        70      79
# 3 150           94        84      49
# 4 168           90        43      64
# 5 154           91        77      75
# 6 163           90        94      66

# %%
attach(data)
# Out:
# The following objects are masked from data (pos = 3):
#
#     Age, Balance, Club, Height_in_Inches, ID, Jersey_Number, Name,
#     Nationality, Overall, Potential, Reactions, Strength, Value_in_M,
#     Wage_in_K, Weight_in_lbs
#
#
# The following objects are masked from data (pos = 4):
#
#     Age, Balance, Club, Height_in_Inches, ID, Jersey_Number, Name,
#     Nationality, Overall, Potential, Reactions, Strength, Value_in_M,
#     Wage_in_K, Weight_in_lbs

# %%
library('tidyverse')

# %%
data %>% distinct(Club)
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# ERROR while rich displaying an object: Error in gsub(chr, html_specials[[chr]], text, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 6. repr::mime2repr[[mime]](obj)
# 7. repr_markdown.data.frame(obj)
# 8. repr_matrix_generic(obj, "\n%s\n\n%s%s\n", sprintf("|%%s\n|%s|\n",
#  .     underline), NULL, " <!--/--> |", " %s |", "%s", "|%s\n",
#  .     " %s |", " %s |", escape_fun = markdown_escape, rows = rows,
#  .     cols = cols, ...)
# 9. lapply(seq_len(nrow(x)), function(r) {
#  .     row <- escape_fun(slice_row(x, r))
#  .     cells <- sprintf(cell, row)
#  .     if (has_rownames) {
#  .         row_head <- sprintf(row_head, escape_fun(rownames(x)[[r]]))
#  .         cells <- c(row_head, cells)
#  .     }
#  .     sprintf(row_wrap, paste(cells, collapse = ""))
#  . })
# 10. FUN(X[[i]], ...)
# 11. escape_fun(slice_row(x, r))
# 12. html_escape(values, do_spaces = FALSE)
# 13. gsub(chr, html_specials[[chr]], text, fixed = TRUE)
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
#    Club
# 1  FC Barcelona
# 2  Juventus
# 3  Paris Saint-Germain
# 4  Manchester United
# 5  Manchester City
# 6  Chelsea
# 7  Real Madrid
# 8  Atl\xe9tico Madrid
# 9  FC Bayern M\xfcnchen
# 10 Tottenham Hotspur
# 11 Liverpool
# 12 Napoli
# 13 Arsenal
# 14 Milan
# 15 Inter
# 16 Lazio
# 17 Borussia Dortmund
# 18 Vissel Kobe
# 19 Olympique Lyonnais
# 20 Roma
# 21 Valencia CF
# 22 Guangzhou Evergrande Taobao FC
# 23 FC Porto
# 24 FC Schalke 04
# 25 Be?ikta? JK
# 26 LA Galaxy
# 27 Sporting CP
# 28 Real Betis
# 29 Olympique de Marseille
# 30 RC Celta
# ⋮  ⋮
# 63 VfL Wolfsburg
# 64 Shakhtar Donetsk
# 65 Toronto FC
# 66 Lokomotiv Moscow
# 67 Sassuolo
# 68 New York City FC
# 69 Fluminense
# 70 PSV
# 71 Levante UD
# 72 Fulham
# 73 Watford
# 74 Atlanta United
# 75 Montpellier HSC
# 76 Galatasaray SK
# 77 Fenerbah\xe7e SK
# 78 SD Eibar
# 79 Los Angeles FC
# 80 Sampdoria
# 81 Al Hilal
# 82 VfB Stuttgart
# 83 SC Braga
# 84 River Plate
# 85 Deportivo Alav\xe9s
# 86
# 87 Eintracht Frankfurt
# 88 Girona FC
# 89 Guangzhou R&F; FC
# 90 Burnley
# 91 Stoke City
# 92 Southampton
